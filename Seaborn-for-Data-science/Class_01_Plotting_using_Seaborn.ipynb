# %% [markdown]
# <a href="https://colab.research.google.com/github/Saifullah785/Python_for_Data_Science/blob/main/Seaborn-for-Data-science/Class_01_Plotting_using_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Why Seaborn?**
#
# **provides a layer of abstraction hence simpler to use**
#
# **better aesthetics**
#
# **more graphs included**
#
# # **Seaborn Roadmap**
#
# **Types of Functions**
#
# **Figure Level**
#
# **Axis level**
#
# # **Main Classification**
#
# **Relational Plot**
#
# 1.scatterplot
#
# 2.Lineplot
#
# **Distribution Plot**
#
# 1.Histogram
#
# 2.kde Plot
#
# 3.Rug Plot
#
# **Categroical Plot**
#
# 1.Barplot
#
# 2.countplot
#
# 3.Boxplot
#
# 4.violin
#
# 5.swarmplot
#
#
#
# **Regression Plot**
#
#
#
# **Matrix PLot**
#
# 1.Heatmap
#
# 2.clustermap
#
# **Multiplots**
#
# 1.Joinplot
#
# 2.pairplot
#
#
# https://seaborn.pydata.org/api.html

# %% [markdown]
# **1.Relational PLot**
#
# to use the statistical relation between 2 or more variables
#
# Bivariate analysis
#
# **Plot under this section**
#
# scatterplot
#
# lineplot

# %%
# scatter plot
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# scatter plot -> axes level functions
sns.scatterplot(x='total_bill',y='tip',data=tips,hue='sex',style='time',size='size')
plt.show()

# %%
# relplot -> figure level -> square shape

sns.relplot(x='total_bill',y='tip',data=tips,hue='sex',style='time',size='size')
plt.show()

# %%
gap = px.data.gapminder()
temp_df = gap[gap['country'] == 'Pakistan']
temp_df
# Out:
#        country continent  year  lifeExp        pop    gdpPercap iso_alpha  \
# 1164  Pakistan      Asia  1952   43.436   41346560   684.597144       PAK
# 1165  Pakistan      Asia  1957   45.557   46679944   747.083529       PAK
# 1166  Pakistan      Asia  1962   47.670   53100671   803.342742       PAK
# 1167  Pakistan      Asia  1967   49.800   60641899   942.408259       PAK
# 1168  Pakistan      Asia  1972   51.929   69325921  1049.938981       PAK
# 1169  Pakistan      Asia  1977   54.043   78152686  1175.921193       PAK
# 1170  Pakistan      Asia  1982   56.158   91462088  1443.429832       PAK
# 1171  Pakistan      Asia  1987   58.245  105186881  1704.686583       PAK
# 1172  Pakistan      Asia  1992   60.838  120065004  1971.829464       PAK
# 1173  Pakistan      Asia  1997   61.818  135564834  2049.350521       PAK
# 1174  Pakistan      Asia  2002   63.610  153403524  2092.712441       PAK
# 1175  Pakistan      Asia  2007   65.483  169270617  2605.947580       PAK
#
# ...

# %%
# axes level function
sns.lineplot(x='year',y='lifeExp',data=temp_df)
plt.show()

# %%
# using relplot
sns.relplot(x='year',y='lifeExp',data=temp_df,kind= 'line')
plt.show()

# %%
# hue -> style
temp_df = gap[gap['country'].isin(['Pakistan','Brazil','Germany'])]
temp_df.sample(5)
# Out:
#        country continent  year  lifeExp        pop     gdpPercap iso_alpha  \
# 179     Brazil  Americas  2007   72.390  190010647   9065.800825       BRA
# 174     Brazil  Americas  1982   63.336  128962939   7030.835878       BRA
# 570    Germany    Europe  1982   73.800   78335266  22031.532740       DEU
# 168     Brazil  Americas  1952   50.917   56602560   2108.944355       BRA
# 1165  Pakistan      Asia  1957   45.557   46679944    747.083529       PAK
#
#       iso_num
# 179        76
# 174        76
# 570       276
# 168        76
# 1165      586

# %%
sns.relplot(x='year',y='lifeExp',data=temp_df,kind='line',hue='country',style='continent',size='continent')
plt.show()

# %%
sns.lineplot(x='year',y='lifeExp',data=temp_df,hue='country',style='country')
plt.show()

# %%
# facet plot -> figure level function -> work with relplot
# it will not work with scatterplot and lineplot
sns.relplot(x='total_bill',y='tip',data=tips,kind='scatter',col='day' , row='sex')
plt.show()

# %%
## it will not work with sns.scatter plot
# sns.scatterplot(x='total_bill',y='tip',data=tips,col='day' , row='sex')
# plt.show()

# %%
# col wrap
sns.relplot(data=gap, x= 'lifeExp',y='gdpPercap',kind='scatter',col='year',col_wrap=3)
plt.show()

# %%
# lineplot in seaborn
sns.scatterplot(x='total_bill',y='tip',data=tips,hue='sex',style='time',size='size')
plt.show()

# %% [markdown]
# # **2.Distribution Plots**
#
# Used to find out the distribution
#
# Range of the observation
#
# Central Tendancy
#
# Is the data bimodal?
#
# Are there outliers?
#
# # **Plots under distribution plot**
#
# histplot
#
# kdeplot
#
# rugplot

# %%
# figure level -> distplot
# axes level -> histplot -> kdeplot -> rugplot

# %%
# ploting univariate histogram
sns.histplot(data=tips, x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.displot(data=tips, x='total_bill',kind='hist')

# %%
# bins parameter
sns.displot(data=tips, x='total_bill',kind='hist',bins=20)

# %%
# it's also possible to visulize the distribution of a categorical variable using the logic of a hitogram.

# Discrete bins are automatically set for categorical variables

# countplot

sns.displot(data=tips, x='day',kind='hist')

# %%
# hue parameter
sns.displot(data=tips, x='tip',kind='hist',hue='sex')

# %%
# element -> step
sns.displot(data=tips, x='tip',kind='hist',hue='sex',element='step')

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.displot(data= titanic,x='age',kind='hist',element='step',hue='survived')

# %%
# faceting using col and row
sns.displot(data=tips, x='tip',kind='hist',col='sex',element='step')

# %%
# sns.kdeplot
# rather than using Discret bins, a KDE plot smooths the observation with a Gaussian kernel, producing a continous density estimate
plt
sns.kdeplot(data=tips, x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# hue -> fill
# sns.kdeplot(data=tips, x='total_bill',hue='sex',fill=True)

sns.displot(data=tips, x='total_bill',kind='kde',hue='sex',fill=True,height=10,aspect=2)

# %%
# Rugplot

# Plot marginal distributions by drawing tricks along the x and y axes.

# this function is intended to complement other plots by showing the location of individual observation in an unobtrusive way.
sns.kdeplot(data=tips, x='total_bill')
sns.regplot(data=tips, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# Bivariate histogram

# A bivariate histogram bins the data within rectangles that tile the plot

# and than shows the count of observation within each rectangle with the fill color

sns.histplot(data=tips, x='total_bill',y='tip')

# sns.distplot(data=tips, x='total_bill', y='tip', kind='hist')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# Bivariate kdeplot
# a bivariate kde plot smothes the (x, y) observations with a 2D Gaussian

sns.kdeplot(data=tips, x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # **3.Matrix Plot**
#
# Heatmap
#
# Clustermap

# %%
# heatmap
# plot rectangular data as color encoded matrix
temp_df = gap.pivot(index='country',columns='year',values='lifeExp')


# axes level function
plt.figure(figsize=(15,15))
sns.heatmap(temp_df)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
# annot
temp_df = gap[gap['continent'] == 'Europe'].pivot(index='country',columns='year',values='lifeExp')
plt.figure(figsize=(15,15))
sns.heatmap(temp_df,annot=True,linewidths=0.5,cmap='summer') # cmap # linewidth
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
# Clustermap

# plot a matrix datset as a hierarchically - clustered heatmap.

# This function requires scipy to be available.

iris = px.data.iris()
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# ...

# %%
sns.clustermap(iris.iloc[:,[0,1,2,3]])

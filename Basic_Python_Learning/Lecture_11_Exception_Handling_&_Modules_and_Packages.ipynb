# %% [markdown]
# <a href="https://colab.research.google.com/github/Saifullah785/Python_for_Data_Science/blob/main/Basic_Python_Learning/Lecture_11_Exception_Handling_%26_Modules_and_Packages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # There are 2 stages where error may happen in a prgram
#
# - During compilation -> Syntax Error
#
# - During execution -> Exceptions

# %% [markdown]
# Syntax Error
#
# - Something in the program is not written according to the program grammer
# - Error is raised by the interpreter/compiler
# - you can solve it by rectifying the program

# %%
# Example of syntax error
print 'hello world'

# %% [markdown]
# # Other examples of syntax error
#
# - Leaving symbols like colon, brackets
# - Misspelling a keyword
# - incorrect indentation
# - empty if/else/loops/class/functions

# %%
a = 5
if a==3
  print('hello')
# Out:
#   File "/tmp/ipython-input-4201232061.py", line 2
#     if a==3
#             ^
# SyntaxError: expected ':'

# %%
a = 5
iff a==3:
  print('hello')
# Out:
#   File "/tmp/ipython-input-521424995.py", line 2
#     iff a==3:
#         ^
# SyntaxError: invalid syntax

# %%
a = 5
if a==3:
print('hello')
# Out:
#   File "/tmp/ipython-input-3610895221.py", line 3
#     print('hello')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
# IndexError
# The IndexError is thrown when trying to access an item at an invalid index.
L = [1,2,3]
L[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-1169124241.py in <cell line: 0>()
#       2 # The IndexError is thrown when trying to access an item at an invalid index.
#       3 L = [1,2,3]
# ----> 4 L[100]
#
# IndexError: list index out of range

# %%
# ModuleNotFoundError
# The ModuleNotFoundError is thrown when a module could not be found.
import mathi
math.floor(5.3)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1819532709.py in <cell line: 0>()
#       1 # ModuleNotFoundError
#       2 # The ModuleNotFoundError is thrown when a module could not be found.
# ----> 3 import mathi
#       4 math.floor(5.3)
#
# ModuleNotFoundError: No module named 'mathi'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# keyError
# The keyError is thrown when a key is not found

d = {'name':'saif'}
d['age']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-45387751.py in <cell line: 0>()
#       3
#       4 d = {'name':'saif'}
# ----> 5 d['age']
#
# KeyError: 'age'

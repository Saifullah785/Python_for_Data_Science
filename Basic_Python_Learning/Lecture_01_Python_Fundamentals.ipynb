# %% [markdown]
# <a href="https://colab.research.google.com/github/Saifullah785/Python_for_Data_Science/blob/main/Basic_Python_Learning/Lecture_01_Python_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Python Output

# %%
# This code prints the string 'hello world' to the console.
print('hello world')
# Out:
# hello world

# %%
# This code prints the string 'saif ali khan' to the console.
print('saif ali khan')
# Out:
# saif ali khan

# %%
# This code attempts to print a variable named salman khan, but it will cause a SyntaxError because variable names cannot contain spaces and it's not defined.
print(salman khan)
# Out:
#   File "/tmp/ipython-input-1115953987.py", line 1
#     print(salman khan)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# This code prints the integer 7 to the console.
print(7)
# Out:
# 7

# %%
# This code prints the floating-point number 7.7 to the console.
print(7.7)
# Out:
# 7.7

# %%
# This code prints the boolean value True to the console.
print(True)
# Out:
# True

# %%
# This code prints multiple values (a string, integers, and a boolean) separated by spaces (the default separator).
print('hello',1,3,5,True)
# Out:
# hello 1 3 5 True

# %%
# This code prints multiple values (a string, integers, and a boolean) separated by a forward slash ('/').
print('Hello',1,4,True,sep='/')
# Out:
# Hello/1/4/True

# %%
# This code prints 'hello' on one line and 'world' on the next line (the default end character is a newline).
print('hello')
print('world')
# Out:
# hello
# world

# %%
# This code prints 'hello' followed by a hyphen, and then 'world' immediately after the hyphen on the same line.
print('hello',end='-')
print('world')
# Out:
# hello-world

# %% [markdown]
# # 2.Data Types

# %%
# This code prints the integer 8 to the console.
print(8)
# Out:
# 8

# %%
# This code prints a very large floating-point number (1 followed by 309 zeros), which exceeds the maximum representable value and results in 'inf' (infinity).
# 1*10^308
print(1e309)
# Out:
# inf

# %%
# This code prints the floating-point number 8.55 and then a very large floating-point number (1.7 followed by 309 zeros) on the next line, which also results in 'inf'.
print(8.55)
print(1.7e309)
# Out:
# 8.55
# inf

# %%
# This code prints the boolean values True and False on separate lines.
print(True)
print(False)
# Out:
# True
# False

# %%
# This code prints the string 'hello world ' to the console.
print('hello world ')
# Out:
# hello world

# %%
# This code prints a complex number (5 + 6i) to the console.
print(5+6j)
# Out:
# (5+6j)

# %%
# This code prints a list containing integers from 1 to 5.
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# This code prints a tuple containing integers from 1 to 5.
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
# This code prints a set containing integers from 1 to 5. Note that sets are unordered, so the output order might vary.
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
# This code prints a dictionary with key-value pairs representing 'name', 'gender', and 'weight'.
print({'name':'saif ali khan','gender':'Male', 'weight':70})
# Out:
# {'name': 'saif ali khan', 'gender': 'Male', 'weight': 70}

# %%
# These lines of code use the type() function to determine and print the data type of various values and data structures (integer, float, complex, list, tuple, set, dictionary).
type(3)
type(4.5)
type(6+5j)
type([1,2,4])
type((1,2,4))
type({1,2,4})
type({'name':'saif ali khan','gender':'Male', 'weight':70})
# Out:
# dict

# %% [markdown]
# # 3. Variable

# %%
# This code assigns the string 'saif' to the variable 'name' and then prints the value of the variable.
name = 'saif'

print(name)
# Out:
# saif

# %%
# This code assigns integer values to variables 'a' and 'b', then prints the sum of 'a' and 'b'.
a = 4
b = 5

print(a + b)
# Out:
# 9

# %%
# This is an example of dynamic typing in Python, where the data type of a variable is determined at runtime.
a = 5

# This is commented out as it represents static typing, which is not how variable declaration works in Python.
# static typing
# int a = 5

# %%
# This is an example of dynamic binding in Python, where the type of the object a variable refers to can change during runtime.
# Initially, 'a' is an integer.
a = 4
print(a)

# Then, 'a' is reassigned to a string.
a = 'ali'
print(a)
# Out:
# 4
# ali

# %%
# This code assigns integer values to variables a, b, and c individually and then prints their values.
a = 1
b = 2
c = 3
print(a,b,c)
# Out:
# 1 2 3

# %%
# This code demonstrates assigning multiple values to multiple variables in a single line (tuple unpacking).
a,b,c =1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
# This code demonstrates assigning the same value to multiple variables in a single line.
a= b= c = 5
print(a,b,c)
# Out:
# 5 5 5

# %% [markdown]
# # Comments

# %%
# this is comments

a =4
b = 6 # like this
print(a+b)
# Out:
# 10

# %% [markdown]
#  # 3.Keywords & Identifiers

# %%
# This is a markdown cell title.
# keywords

# %%
# Identifiers
# you can not start with a digit
name1 = 'saif'
print(name1)
# you can use special chars -> _
_ = 'saif'
print(_)

# identifier can not be keyword
# Out:
# saif
# saif

# %% [markdown]
# # 5.User Input

# %%
# static Vs Dynamic
input('enter your email')
# Out:
# enter your emailsaif@gmail.com
# 'saif@gmail.com'

# %%
# take input from users and store them in a variable
fnum = int(input('enter first number'))
snum = int(input('enter second number'))
print(type(fnum),type(snum))
# add the 2 variables
result = fnum + snum
print(result)
# Out:
# enter first number5
# enter second number6
# <class 'int'> <class 'int'>
# 11

# %% [markdown]
# # 6.Type Conversion

# %%
# implicit Vs Explicit
print(5 + 5.6)

print(type(5),type(5.6))

a = float('5.0')
print(4 + a)
# Out:
# 10.6
# <class 'int'> <class 'float'>
# 9.0

# %%
# This line is commented out because converting a complex number directly to an integer is not possible in Python.
# a = int(4+5j)

# This code converts the integer 4 to a string.
str(4)

# This code converts the integer 4 to a float.
float(4)
# Out:
# 4.0

# %% [markdown]
# # 7.Literals

# %%
a = 0b1010 #Binary Literals
b = 100 #Decimal Literal
c = 0o310 #Octal Literal
d = 0x12c #Hexadecimal Literal

#Float Literal
float_1 = 10.5
float_2 = 1.5e2 #= 1.5 * 10^2
float_3 = 1.5e-3 #= 1.5 * 10^-3

#Complex Literal
x = 3.14j

print(a, b, c, d)
print(float_1, float_2,float_3)
print(x, x.imag, x.real)

# %%
a = 0b1010 #Binary Literals
print(a)
# Out:
# 10

# %%
c = 0o310 #Octal Literal
print(c)
# Out:
# 200

# %%
d = 0x12c #Hexadecimal Literal
print(d)
# Out:
# 300

# %%
x = 3.14j
print(x.real,x.imag)
# Out:
# 0.0 3.14

# %%
string = 'This is Python'
strings = "This is Python"
char = "C"
multiline_str = """This is a multiline string with more than one line code."""
unicode = u"\U0001f600\U0001F606\U0001F923"
raw_str = r"raw \n string"

print(string)
print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# This is Python
# This is Python
# C
# This is a multiline string with more than one line code.
# 😀😆🤣
# raw \n string

# %%
a = True + 4
b = False + 10

print("a:", a)
print("b:", b)
# Out:
# a: 5
# b: 10

# %%
a  = None
print(a)
# Out:
# None

# %%
# This code assigns None to variable 'k' and integers to 'a' and 'b', then prints a string indicating program execution.
k = None
a =5
b = 6
print('Program exe')
# Out:
# Program exe

# %% [markdown]
# # 8.Operators

# %%
# This cell lists different types of operators in Python.
# Arithmetic
# Relational
# Logical
# Bitwise
# Assignment
# Membership

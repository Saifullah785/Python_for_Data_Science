# %% [markdown]
# <a href="https://colab.research.google.com/github/Saifullah785/Python_for_Data_Science/blob/main/Basic_Python_Learning/Lecture_07_OOP_Part_01_Object_%26_Class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This cell demonstrates an AttributeError when calling .upper() on a list.
L = [1,2,3]

L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1775374810.py in <cell line: 0>()
#       1 L = [1,2,3]
#       2
# ----> 3 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
# This cell demonstrates an AttributeError when calling .append() on a string.
s = 'hello'
s.append('x')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-666329863.py in <cell line: 0>()
#       1 s = 'hello'
# ----> 2 s.append('x')
#
# AttributeError: 'str' object has no attribute 'append'

# %%
# This cell prints the type of a list.
L = [1,2,3]
print(type(L))
# Out:
# <class 'list'>

# %%
# This cell creates a list named s.
s = [1,2,3]

# %%
# This cell contains a comment about object creation syntax.
# syntax to create an object
# objectname = classname()

# %%
# This cell creates a list using an object literal.
# object literal
L = [1,2,3]

# %%
# This cell creates an empty list using the list() constructor.
L = list()
L
# Out:
# []

# %%
# This cell creates an empty string using the str() constructor.
s = str()
s
# Out:
# ''

# %%
# This cell contains a comment about Pascal Case.
# pascal case
helloworld

# %%
# This cell defines an Atm class with methods for ATM operations.
class Atm:

  # constructor (special function)->superpower ->
  def __init__(self):
    self.pin = ''
    self.balance = 0
    self.menu()

  def menu(self):
    user_input = input("""
    hi how can i help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)
    if user_input == '1':
      self.create_pin()
    elif user_input == '2':

      self.change_pin()
    elif user_input == '3':

      self.check_balance()
    elif user_input == '4':

      self.withdraw()
    else:
      exit()
  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.balance = user_balance
    print('pin created successfully')
    self.menu()

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
      self.menu()
    else:
      print('nai karne de sakta re baba')
      self.menu()

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.balance:
        self.balance = self.balance - amount
        print('withdrawl successful.balance is',self.balance)
      else:
        print('abe garib')
    else:
      print('sale chor')

# %%
# This cell creates an instance of the Atm class and interacts with the menu.
obj = Atm()
# Out:
#     hi how can i help you?
#     1. Press 1 to create pin
#     2. Press 2 to change pin
#     3. Press 3 to check balance
#     4. Press 4 to withdraw
#     5. Anything else to exit
#     1
# enter your pin1122
# enter balance10000
# pin created successfully
#
#     hi how can i help you?
#     1. Press 1 to create pin
#     2. Press 2 to change pin
#     3. Press 3 to check balance
#     4. Press 4 to withdraw
#     5. Anything else to exit
#     4
# enter the pin1122
# enter the amount2000
# withdrawl successful.balance is 8000

# %%
# This cell prints the type of the object created from the Atm class.
print(type(obj))
# Out:
# <class '__main__.Atm'>

# %%
# This cell creates another instance of the Atm class and interacts with the menu.
obj2 = Atm()
# Out:
#     hi how can i help you?
#     1. Press 1 to create pin
#     2. Press 2 to change pin
#     3. Press 3 to check balance
#     4. Press 4 to withdraw
#     5. Anything else to exit
#     1
# enter your pin11
# enter balance40000
# pin created successfully
#
#     hi how can i help you?
#     1. Press 1 to create pin
#     2. Press 2 to change pin
#     3. Press 3 to check balance
#     4. Press 4 to withdraw
#     5. Anything else to exit
#     4
# enter the pin11
# enter the amount20
# withdrawl successful.balance is 39980

# %%
# This cell prints the memory address of the obj2 instance.
id(obj2)
# Out:
# 136620083963872

# %%
# This cell shows examples of a function and a method.
L = [1,2,3]
len(L) # function ->bcos it is outside the list class
l.append() # method -> bcos it is inside the list class

# %%
# This cell defines a simple class Temp and creates an instance.
class Temp:
  def __init__(self):
    print('hello')

obj = Temp()
# Out:
# hello

# %%
# This cell performs a simple arithmetic calculation.
3/4*1/2
# Out:
# 0.375

# %%
# This cell defines a fraction class with methods for arithmetic operations and decimal conversion.
class fraction:
  # parameterized constructor
  def __init__(self,x,y):
    self.num = x
    self.den = y
  def __str__(self):
    return '{}/{}'.format(self.num,self.den)

  def __add__(self,other):
    new_num = self.num*other.den + other.num*self.den
    new_den = self.den*other.den

    return '{}/{}'.format(new_num,new_den)
  def __sub__(self,other):
    new_num = self.num*other.den - other.num*self.den
    new_den = self.den*other.den

    return '{}/{}'.format(new_num,new_den)

  def __mul__(self,other):
    new_num = self.num*other.num
    new_den = self.den*other.den

    return '{}/{}'.format(new_num,new_den)

  def __truediv__(self,other):
    new_num = self.num*other.den
    new_den = self.den*other.num

    return '{}/{}'.format(new_num,new_den)

  def convert_to_decimal(self):
    return self.num/self.den

# %%
# This cell creates two instances of the fraction class.
fr1 = fraction(3,4)
fr2 = fraction(1,2)

# %%
# This cell calls the convert_to_decimal method on a fraction object.
fr1.convert_to_decimal()
# 3/4
# Out:
# 0.75

# %%
# This cell demonstrates arithmetic operations using the fraction class.
print(fr1 + fr2)
print(fr1 - fr2)
print(fr1 * fr2)
print(fr1 / fr2)
# Out:
# 10/8
# 2/8
# 3/8
# 6/4

# %%
# This cell demonstrates a TypeError when trying to add two sets using the + operator.
s1 = {1,2,3}
s2 = {3,4,5}

s1 + s2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3034308854.py in <cell line: 0>()
#       2 s2 = {3,4,5}
#       3
# ----> 4 s1 + s2
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
# This cell prints the result of subtracting two fraction objects.
print(fr1 - fr2)
# Out:
# 2/8

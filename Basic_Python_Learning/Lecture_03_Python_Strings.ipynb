# %% [markdown]
# <a href="https://colab.research.google.com/github/Saifullah785/Python_for_Data_Science/blob/main/Basic_Python_Learning/Lecture_03_Python_Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Strings are sequence of Characters**
#
# ## In Python specifically, string are a sequence of Unicode Characters
#
# - Creating strings
#
# - Accessing Strings
#
# - Adding Chars to strings
#
# - Editing Strings
#
# - Deleting Strings
#
# - Operations On Strings
#
# - String Functions

# %%
s = 'hello'
s = "hello"

# multiline strings

s = '''hello'''

"""hello"""

s = str("hello")
print(s)
# Out:
# hello

# %%
"it's raining outside"
# Out:
# "it's raining outside"

# %% [markdown]
# ## Accessing Substrings from a String

# %%
# Positive Indexing
s = 'hello world'
print(s[0])
print(s[1])
# Out:
# h
# e

# %%
# Negative indexing

s = 'hello world'
print(s[-1])
print(s[-2],s[-3])
# Out:
# d
# l r

# %%
# silicing

s = 'hello world'
print(s[0:5])
print(s[0:6:2])
print(s[6:0:-2])
# Out:
# hello
# hlo
# wol

# %%
print(s[::-1])
# Out:
# dlrow olleh

# %%
s = 'hello world'
print(s[-5:])
print(s[-1:-6:-1])
# Out:
# world
# dlrow

# %% [markdown]
# # Editing and Deleting in Strings

# %%
s= 'hello world'
s[0] = 'H'

# Python strings are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-490658618.py in <cell line: 0>()
#       1 s= 'hello world'
# ----> 2 s[0] = 'H'
#       3
#       4 # Python strings are immutable
#
# TypeError: 'str' object does not support item assignment

# %%
s = 'hello world'
del s
print(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2968721042.py in <cell line: 0>()
#       1 s = 'hello world'
#       2 del s
# ----> 3 print(s)
#
# NameError: name 's' is not defined

# %%
s = 'hello world'
del s[-1:-5:2]
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-266792670.py in <cell line: 0>()
#       1 s = 'hello world'
# ----> 2 del s[-1:-5:2]
#       3 print(s)
#
# TypeError: 'str' object does not support item deletion

# %% [markdown]
# # Operation on Strings
#
# - Arithmetic operations
#
# - Relational Operations
#
# - Logical Operations
#
# - Loops on Strings
#
# - Membership Operations

# %%
print('pind'+ ' ' +'karachi')
# Out:
# pind karachi

# %%
print('karachi'*5)
# Out:
# karachikarachikarachikarachikarachi

# %%
print('*'*50)
# Out:
# **************************************************

# %%
# Relational opertors in string
'delhi' != 'delhi'
# Out:
# False

# %%
'karachi'>'pind'
# lexiographically
# Out:
# False

# %%
'Pind' > 'Pind'
# Out:
# False

# %%
'hello' and 'world'
# Out:
# 'world'

# %%
'hello' or 'world'
# Out:
# 'hello'

# %%
not ''
# Out:
# True

# %%
not 'hello'
# Out:
# False

# %%
for i in 'hello world':
    print(i)
# Out:
# h
# e
# l
# l
# o
#
# w
# o
# r
# l
# d

# %%
for i in 'karachi':
  print('pune')
# Out:
# pune
# pune
# pune
# pune
# pune
# pune
# pune

# %%
'D' in 'Karachi'
# Out:
# False

# %%
'P' in 'Pindi'
# Out:
# True

# %% [markdown]
# # Common Functions
#
# - len
#
# - max
#
# - min
#
# - sorted

# %%
s = 'hello world'
len(s)
# Out:
# 11

# %%
s = 'hello world'
max(s)
# Out:
# 'w'

# %%
s = 'hello world'
min(s)
# Out:
# ' '

# %%
s = 'hello world'
sorted(s,reverse=True)
# Out:
# ['w', 'r', 'o', 'o', 'l', 'l', 'l', 'h', 'e', 'd', ' ']

# %% [markdown]
# # Capitalize/Title/Upper/Lower/Swapcase

# %%
s = 'hello world'
s.capitalize()
# Out:
# 'Hello world'

# %%
s.title()
# Out:
# 'Hello World'

# %%
s.upper()
# Out:
# 'HELLO WORLD'

# %%
'Hello World'.lower()
# Out:
# 'hello world'

# %%
'hellO WorLD'.swapcase()
# Out:
# 'HELLo wORld'

# %% [markdown]
# # Count/Find/Index

# %%
'my name is saif'.count('s')
# Out:
# 2

# %%
'my name is saif'.find('f')
# Out:
# 14

# %%
'my name is saif'.index('is')
# Out:
# 8

# %% [markdown]
# # endwith/startswith

# %%
'my name is saif'.endswith('s')
# Out:
# False

# %%
'my name is saif'.startswith('m')
# Out:
# True

# %% [markdown]
# # format

# %%
name = 'saif'
gender= 'male'

'Hi my name is {} and i am a {}'.format(name,gender)
# Out:
# 'Hi my name is saif and i am a male'

# %% [markdown]
# # isalnum/isalpha/isdigit/isidentifier

# %%
'saif1234%'.isalnum()
# Out:
# False

# %%
'saif1234'.isalpha()
# Out:
# False

# %%
'123saif'.isdigit()
# Out:
# False

# %%
'1name'.isidentifier()
# Out:
# False

# %%
'first_name'.isidentifier()
# Out:
# True

# %% [markdown]
# # Split /Join

# %%
'hi my name is saif'.split('is')
# Out:
# ['hi my name ', ' saif']

# %%
'hi my name is saif'.split()
# Out:
# ['hi', 'my', 'name', 'is', 'saif']

# %%
" ".join(['hi', 'my', 'name', 'is', 'saif'])
# Out:
# 'hi my name is saif'

# %%
"- ".join(['hi', 'my', 'name', 'is', 'saif'])
# Out:
# 'hi- my- name- is- saif'

# %% [markdown]
# # Replace

# %%
'hi my name is saif'.replace('is','was')
# Out:
# 'hi my name was saif'

# %% [markdown]
# # Strip

# %%
'hi my name is saif'.strip()
# Out:
# 'hi my name is saif'

# %% [markdown]
# # Example Programs

# %%
# Find the length of a given string without using the len() function

s = input('enter the string')

counter = 0

for i in s:
  counter +=1

print('length of string is', counter)
# Out:
# enter the stringhello world
# length of string is 11

# %%
# Extract username from a given email.
# Eg if the email is saif123@gmail.com
# then the username should be saif123

s = input('enter the email')

pos = s.index('@')
print(s[0:pos])
# Out:
# enter the emailsaif123@gmail.com
# saif123

# %%
# Count the frequency of a particular character in a provided string.
# EG 'hello how are you' is the string, the frequency of h in this string is 2

s = input('enter the email')
term = input("what would like to search for")

counter = 0
for i in s:
  if i == term:
    counter +=1

print('frequency',counter)
# Out:
# enter the emailemailsaif11@gmail.com
# what would like to search fora
# frequency 3

# %%
# Write a program which can remove a particular character from a string.
s = input('enter the string')
term = input('what would like to remove')

result = ''

for i in s:
  if i != term:
    result = result + i

print(result)
# Out:
# enter the stringsaif ali
# what would like to removei
# saf al

# %%
# write a program that can check whether a given string is pallindrome or not
## abba

s = input('enter the string')

flag = True
for i in range(0,len(s)//2):
  if s[i] != s[len(s) - i -1]:
    flag = False
    print('not a pallindrome')
    break

if flag:
  print('pallindrome')
# Out:
# enter the stringsaif
# not a pallindrome

# %%
# write a program to count the number of words in a string withoud split()

s = input('enter the string')
L = []
temp = ''
for i in s:

  if i != ' ':
    temp = temp + i
  else:
    L.append(temp)
    temp = ''

L.append(temp)
print(L)
print(len(L))
# Out:
# enter the stringhi how are you?
# ['hi', 'how', 'are', 'you?']
# 4

# %%
# write a python program to convert a string to title case without using the title()

s = input('enter the string')

L = []
for i in s.split():
  L.append(i[0].upper() + i[1:].lower())

print(" ".join(L))
# Out:
# enter the stringhi my name is saif ali
# Hi My Name Is Saif Ali

# %%
# write a program that can convert an integer to string.

number = int(input('enter the number'))

digits = '0123456789'
result = ''

while number != 0:
  result = digits[number % 10] + result
  number = number // 10

print(result)
print(type(result))
# Out:
# enter the number33
# 33
# <class 'str'>

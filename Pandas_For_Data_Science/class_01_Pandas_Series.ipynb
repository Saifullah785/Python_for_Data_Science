# %% [markdown]
# <a href="https://colab.research.google.com/github/Saifullah785/Python_for_Data_Science/blob/main/Pandas_For_Data_Science/class_01_Pandas_Series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### What is Pandas
#
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language.
#
# https://pandas.pydata.org/about/index.html

# %% [markdown]
# ### Pandas Series
#
# A Pandas Series is like a column in a table. It is a 1-D array holding data of any type.

# %%
# importing pandas
import numpy as np
import pandas as pd

# %%
# string
country = ['pakistan','india','nepal','united state']
pd.Series(country)
# Out:
# 0        pakistan
# 1           india
# 2           nepal
# 3    united state
# dtype: object

# %%
# integers
num = [18,29,39,49,59]
pd.Series(num)
# Out:
# 0    18
# 1    29
# 2    39
# 3    49
# 4    59
# dtype: int64

# %%
#  custom index
marks = [67,57,89,100]
subjects = ['maths','english','urdu','science']
pd.Series(marks,index=subjects)
# Out:
# maths       67
# english     57
# urdu        89
# science    100
# dtype: int64

# %%
# setting a name
marks = pd.Series(marks,index=subjects,name='saif ke marks')
marks
# Out:
# maths       67
# english     57
# urdu        89
# science    100
# Name: saif ke marks, dtype: int64

# %% [markdown]
# **Series from dict**

# %%
# code
marks ={
    'maths':67,
    'english':57,
    'urdu':67,
    'science':100
}
marks_series = pd.Series(marks,name='saif ke marks')
marks_series
# Out:
# maths       67
# english     57
# urdu        67
# science    100
# Name: saif ke marks, dtype: int64

# %% [markdown]
# **Series Attributes**

# %%
# size
marks_series.size
# Out:
# 4

# %%
# dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
# name
marks_series.name
# Out:
# 'saif ke marks'

# %%
# is_uniqe
marks_series.is_unique
# Out:
# False

# %%
# index
marks_series.index
# Out:
# Index(['maths', 'english', 'urdu', 'science'], dtype='object')

# %%
# values
marks_series.values
# Out:
# array([ 67,  57,  67, 100])

# %% [markdown]
# **Series using read_csv**

# %%
# with one col
subs = pd.read_csv('/content/subs.csv').iloc[:, 0]

# %%
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# with 2 cols
vk = pd.read_csv('/content/kohli_ipl.csv',index_col='match_no').iloc[:,0:2]

# %%
# with 2 cols
movies = pd.read_csv('/content/bollywood.csv',index_col='movie').iloc[:,0:2]

# %% [markdown]
# **Series methods**

# %%
# head and tail
subs.head()
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
subs.tail()
# Out:
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, dtype: int64

# %%
vk.tail(10)
# Out:
#           runs
# match_no
# 206          0
# 207          0
# 208          9
# 209         58
# 210         30
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7

# %%
# sample
movies.sample(5)
# Out:
#                                         lead
# movie
# Revolver Rani                 Kangana Ranaut
# Out of Control (2003 film)  Riteish Deshmukh
# Aabra Ka Daabra                  Naveen Bawa
# Sarkar (2005 film)          Amitabh Bachchan
# Badlapur (film)                 Varun Dhawan

# %%
movies
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
# value_counts -> movies
movies.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Naveen Bawa          1
# Naushaad Abbas       1
# Nauheed Cyrusi       1
# Natalia Janoszek     1
# Nishikant Kamat      1
# Name: count, Length: 566, dtype: int64

# %%
vk
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
# sort_values -> inplace
vk.sort_values(by='runs', ascending=False).head(1).values
# Out:
# array([[113]])

# %%
# sort_index -> inplace -> movie
# vk.sort_values(by='runs', ascending=False,inplace=True)

# %%
vk
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
# sort_index -> inplace -> movie
movies.sort_index()
# Out:
#                                         lead
# movie
# 1920 (film)                 Rajniesh Duggall
# 1920: London                   Sharman Joshi
# 1920: The Evil Returns           Vicky Ahuja
# 1971 (2007 film)              Manoj Bajpayee
# 2 States (2014 film)            Arjun Kapoor
# ...                                      ...
# Zindagi 50-50                    Veena Malik
# Zindagi Na Milegi Dobara      Hrithik Roshan
# Zindagi Tere Naam         Mithun Chakraborty
# Zokkomon                     Darsheel Safary
# Zor Lagaa Ke...Haiya!          Meghan Jadhav
#
# [1500 rows x 1 columns]

# %% [markdown]
# # **Series Maths Methods**

# %%
# count
vk.count()
# Out:
# runs    215
# dtype: int64

# %%
# sum -> product
subs.sum()
# subs.product()
# Out:
# np.int64(49510)

# %%
# mean -> median -> mode -> std -> var
# subs.mean()
# print(vk.median())
# print(vk.mean())
# print (movies.mode())
print(subs.std())
print(vk.var())
# Out:
# 62.67502303725269
# runs    688.002478
# dtype: float64

# %%
# min/max
print(subs.min())
print(subs.max())
# Out:
# 33
# 396

# %%
# describes
subs.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %% [markdown]
# # **Series Indexing**

# %%
# integer indexing
x = pd.Series([1,2,3,4,5,6,7,8,9])
x[2]
# Out:
# np.int64(3)

# %%
# negative indexing
# x[-1] negative indexing is not working in pandas

# %%
vk
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
vk.iloc[1]
# Out:
# runs    23
# Name: 2, dtype: int64

# %%
print(movies.iloc[0])
# Out:
# lead    Vicky Kaushal
# Name: Uri: The Surgical Strike, dtype: object

# %%
print(movies.iloc[0, 0])
# Out:
# Vicky Kaushal

# %%
# slicing
vk.iloc[1:10]
# Out:
#           runs
# match_no
# 2           23
# 3           13
# 4           12
# 5            1
# 6            9
# 7           34
# 8            0
# 9           21
# 10           3

# %%
vk.iloc[-5:]
# Out:
#           runs
# match_no
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7

# %%
movies.iloc[::2]
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# The Accidental Prime Minister (film)       Anupam Kher
# Evening Shadows                       Mona Ambegaonkar
# Fraud Saiyaan                             Arshad Warsi
# Manikarnika: The Queen of Jhansi        Kangana Ranaut
# ...                                                ...
# Raaz (2002 film)                            Dino Morea
# Waisa Bhi Hota Hai Part II                Arshad Warsi
# Kaante                                Amitabh Bachchan
# Aankhen (2002 film)                   Amitabh Bachchan
# Company (film)                              Ajay Devgn
#
# [750 rows x 1 columns]

# %%
# fancy indexing
vk.iloc[[1, 3, 5]]
# Out:
#           runs
# match_no
# 2           23
# 4           12
# 6            9

# %%
# prompt: indexing with labels -> fancy indexing

vk.loc[[1, 3, 5]]
# Out:
#           runs
# match_no
# 1            1
# 3           13
# 5            1

# %% [markdown]
# # **Editing Series**

# %%
# using indexing
marks_series
# Out:
# maths      100
# english     57
# urdu        67
# science    100
# sst         99
# Name: saif ke marks, dtype: int64

# %%
marks_series[0]=100
# Out:
# <ipython-input-89-a2997e6429f4>:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_series[0]=100

# %%
# what if an index does not exist
marks_series["sst"]=99

# %%
# slicing
# runs_series [2:4] =[100,100]
# runs_ser

# %%
# # fancy indexing
# runs_ser[[0,1,2,3]] =[0,0,0]
# runs_ser

# %%
# using index label
movies['2 States(2014 film)'] = 'Alia Butt'

# %%
movies
# Out:
#                                                   lead 2 States(2014 film)
# movie
# Uri: The Surgical Strike                 Vicky Kaushal           Alia Butt
# Battalion 609                              Vicky Ahuja           Alia Butt
# The Accidental Prime Minister (film)       Anupam Kher           Alia Butt
# Why Cheat India                          Emraan Hashmi           Alia Butt
# Evening Shadows                       Mona Ambegaonkar           Alia Butt
# ...                                                ...                 ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan           Alia Butt
# Aankhen (2002 film)                   Amitabh Bachchan           Alia Butt
# Saathiya (film)                           Vivek Oberoi           Alia Butt
# Company (film)                              Ajay Devgn           Alia Butt
# Awara Paagal Deewana                      Akshay Kumar           Alia Butt
#
# [1500 rows x 2 columns]

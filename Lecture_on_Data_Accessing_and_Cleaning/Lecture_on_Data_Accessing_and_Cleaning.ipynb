# %% [markdown]
# <a href="https://colab.research.google.com/github/Saifullah785/Python_for_Data_Science/blob/main/Lecture_on_Data_Accessing_and_Cleaning/Lecture_on_Data_Accessing_and_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Description of this Notebook:**
#
# This notebook documents a data analysis process for a clinical trial dataset.
#
# It starts by loading four datasets: patients, treatments, adverse_reactions, and treatments_cut.
#
# The notebook includes initial data assessment steps using functions like .head(), .tail(), .sample(), .info(), .isnull().sum(), and .duplicated().
#
# It identifies and documents various data quality and tidiness issues.
#
# The notebook then proceeds to the data cleaning phase, creating copies of the original dataframes.
#
# Cleaning steps include handling missing values, calculating hba1c_change, and extracting phone numbers and email addresses from the contact information using a custom function with regular expressions.
#
# The two treatment dataframes (treatments and treatments_cut) are concatenated.
#
# The combined treatment dataframe is then melted and split to separate the dosage ranges into start and end values.
#
# The 'u' character is removed from the dosage columns, and their data types are converted to integer.
#
# Finally, the treatments dataframe is merged with the adverse reactions dataframe and a sample of the cleaned data is displayed.

# %% [markdown]
# # **Data Analysis Process**
#
# 1.Asking Questions
#
# 2.Data Wrangling
#
# **a.Gathering Data**
#
# -i.CSV files
#
# -ii. Apis
#
# -iii.Web Scraping
#
# -iv.Databases
#
#
# **b.Assessing Data**
#
# **c.Cleaning Data**
#
# # **3.Exploratory Data Analysis**
#
# # **4.Drawing Conclusion**
#
# # **5.Comunicating Results**

# %% [markdown]
# # **Summary of today's session**
#
# You have to become Sherlock
#
# Will try to create a framework
#
# Frameworks may vary
#
# The goal is to give you idea

# %% [markdown]
# # **1.Data Wrangling**
#
# Data Gathering
#
# Data Accessing
#
# Data Cleaning

# %% [markdown]
# **1b.Data Accessing**
#
# in this step, the data is to be understand more deeply, before implementing methods to clean it,you will definitely need to have a better idea about what the data is about

# %% [markdown]
# Types of Unclean Data
#
# There are 2 kinds of unclean data

# %% [markdown]
# **Dirty Data (Data with Quality issues ):**
#
# Dirty data, also known as how quality data.low quality data has content issues.
#
# Duplicated Data
#
# Missing Data
#
# Corrupt Data
#
# Inaccurate Data

# %% [markdown]
# **Massy Data (Data with tidiness issures):**
#
# Massy data also known as untidy data. untidy data has structural issues.
#
# Tidy data has the following properties:
#
# Each variable forms a column
#
# Each observation form a row
#
# Each observation unit forms a table

# %%
# Import the necessary libraries: numpy for numerical operations and pandas for data manipulation.
import numpy as np
import pandas as pd

# %%
# Load the four CSV files into pandas DataFrames.
patients = pd.read_csv('patients.csv')
treatments = pd.read_csv('treatments.csv')
adverse_reactions = pd.read_csv('adverse_reactions.csv')
treatments_cut = pd.read_csv('treatments_cut.csv')

# %%
# Display the first 5 rows of the 'patients' DataFrame to get a quick overview of the data.
patients.head()
# Out:
#    patient_id assigned_sex given_name  surname                    address  \
# 0           1       female        Zoe  Wellish       576 Brown Bear Drive
# 1           2       female     Pamela     Hill  2370 University Hill Road
# 2           3         male        Jae   Debord      1493 Poling Farm Road
# 3           4         male       Liêm     Phan        2335 Webster Street
# 4           5         male        Tim  Neudorf       1428 Turkey Pen Lane
#
#                 city       state  zip_code        country  \
# 0  Rancho California  California   92390.0  United States
# 1          Armstrong    Illinois   61812.0  United States
# 2               York    Nebraska   68467.0  United States
# 3         Woodbridge          NJ    7095.0  United States
# 4             Dothan          AL   36303.0  United States
#
#                                       contact  birthdate  weight  height   bmi
# 0        951-719-9170ZoeWellish@superrito.com  7/10/1976   121.7      66  19.6
# ...

# %%
# Display the first 5 rows of the 'treatments' DataFrame.
treatments.head()
# Out:
#   given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0   veronika    jindrová  41u - 48u          -         7.63       7.20
# 1     elliot  richardson          -  40u - 45u         7.56       7.09
# 2   yukitaka    takenaka          -  39u - 36u         7.68       7.25
# 3       skye  gormanston  33u - 36u          -         7.97       7.62
# 4     alissa      montez          -  33u - 29u         7.78       7.46
#
#    hba1c_change
# 0           NaN
# 1          0.97
# 2           NaN
# 3          0.35
# 4          0.32

# %%
# Display the first 5 rows of the 'treatments_cut' DataFrame.
treatments_cut.head()
# Out:
#   given_name    surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0      jožka  resanovič  22u - 30u          -         7.56       7.22
# 1  inunnguaq   heilmann  57u - 67u          -         7.85       7.45
# 2      alwin   svensson  36u - 39u          -         7.78       7.34
# 3        thể      lương          -  61u - 64u         7.64       7.22
# 4     amanda    ribeiro  36u - 44u          -         7.85       7.47
#
#    hba1c_change
# 0          0.34
# 1           NaN
# 2           NaN
# 3          0.92
# 4          0.38

# %%
# Display the first 5 rows of the 'adverse_reactions' DataFrame.
adverse_reactions.head()
# Out:
#   given_name     surname           adverse_reaction
# 0      berta  napolitani  injection site discomfort
# 1       lena        baer               hypoglycemia
# 2     joseph         day               hypoglycemia
# 3     flavia  fiorentino                      cough
# 4    manouck     wubbels          throat irritation

# %%
# Get the number of rows and columns in the 'patients' DataFrame.
patients.shape
# Out:
# (503, 14)

# %%
# Get the number of rows and columns in the 'treatments' DataFrame.
treatments.shape
# Out:
# (280, 7)

# %%
# Get the number of rows and columns in the 'treatments_cut' DataFrame.
treatments_cut.shape
# Out:
# (70, 7)

# %%
# Get the number of rows and columns in the 'adverse_reactions' DataFrame.
adverse_reactions.shape
# Out:
# (34, 3)

# %% [markdown]
# # **1.Write a summary for your data**
#
# This a dataset about 500 patients of which 350 patients participated in a clinical trial. None of the Patients were using Novadra (a popular injectable isulin) or Auralin (the oral insulin being researched) as their primary source of insulin before.
#
# All were experiencing elevated Hba1c levels.
#
# All 350 patients were treated with novodra to establish a baseline HBA 1C level and insulin dose. after 4 weeks, which isn't enough time to capture all the change  in HbA 1C that can be attributed by the switch to Auralin or Novodra:
#
# >175 patients switched to Auralin for 24 weeks
#
# >175 patients continued using Novodra for 24 weeks
#
# Data about patients feeling some adverse effects is also recorded

# %% [markdown]
# ### 2. Write Column descriptions
#
# #### **Table** -> `patients`:
#
# - `patient_id`: the unique identifier for each patient in the Master Patient Index (i.e. patient database) of the pharmaceutical company that is producing Auralin
# - `assigned_sex`: the assigned sex of each patient at birth (male or female)
# - `given_name`: the given name (i.e. first name) of each patient
# - `surname`: the surname (i.e. last name) of each patient
# - `address`: the main address for each patient
# - `city`: the corresponding city for the main address of each patient
# - `state`: the corresponding state for the main address of each patient
# - `zip_code`: the corresponding zip code for the main address of each patient
# - `country`: the corresponding country for the main address of each patient (all United states for this clinical trial)
# - `contact`: phone number and email information for each patient
# - `birthdate`: the date of birth of each patient (month/day/year). The inclusion criteria for this clinical trial is age >= 18 (there is no maximum age because diabetes is a growing problem among the elderly population)
# - `weight`: the weight of each patient in pounds (lbs)
# - `height`: the height of each patient in inches (in)
# - `bmi`: the Body Mass Index (BMI) of each patient. BMI is a simple calculation using a person's height and weight. The formula is BMI = kg/m2 where kg is a person's weight in kilograms and m2 is their height in metres squared. A BMI of 25.0 or more is overweight, while the healthy range is 18.5 to 24.9. The inclusion criteria for this clinical trial is 16 >= BMI >= 38.

# %% [markdown]
# #### **Table** -> `treatments` and `treatment_cut`:
#
# - `given_name`:
#
# the given name of each patient in the Master Patient Index that took part in the clinical trial
#
# - `surname`:
#
# the surname of each patient in the Master Patient Index that took part in the clinical trial
#
# - `auralin`:
#
# the baseline median daily dose of insulin from the week prior to switching to Auralin (the number before the dash) and the ending median daily dose of insulin at the end of the 24 weeks of treatment measured over the 24th week of treatment (the number after the dash). Both are measured in units (shortform 'u'), which is the international unit of measurement and the standard measurement for insulin.
#
# - `novodra`:
#
# same as above, except for patients that continued treatment with Novodra
#
# - `hba1c_start`:
#
# the patient's HbA1c level at the beginning of the first week of treatment. HbA1c stands for Hemoglobin A1c. The HbA1c test measures what the average blood sugar has been over the past three months. It is thus a powerful way to get an overall sense of how well diabetes has been controlled. Everyone with diabetes should have this test 2 to 4 times per year. Measured in %.
#
# - `hba1c_end`:
#
# the patient's HbA1c level at the end of the last week of treatment
#
# - `hba1c_change`:
#
# the change in the patient's HbA1c level from the start of treatment to the end, i.e., hba1c_start - hba1c_end. For Auralin to be deemed effective, it must be "noninferior" to Novodra, the current standard for insulin. This "noninferiority" is statistically defined as the upper bound of the 95% confidence interval being less than 0.4% for the difference between the mean HbA1c changes for Novodra and Auralin (i.e. Novodra minus Auralin).

# %% [markdown]
# #### **Table** -> `adverse_reactions`
#
# - `given_name`: the given name of each patient in the Master Patient Index that took part in the clinical trial and had an adverse reaction (includes both patients treated Auralin and Novodra)
# - `surname`: the surname of each patient in the Master Patient Index that took part in the clinical trial and had an adverse reaction (includes both patients treated Auralin and Novodra)
# - `adverse_reaction`: the adverse reaction reported by the patient

# %% [markdown]
# ### 3. Add any additional information
#
# Additional useful information:
#
# - Insulin resistance varies person to person, which is why both starting median daily dose and ending median daily dose are required, i.e., to calculate change in dose.
# - It is important to test drugs and medical products in the people they are meant to help. People of different age, race, sex, and ethnic group must be included in clinical trials. This diversity is reflected in the patients table.

# %% [markdown]
# ### Types of Assessment
# There are 2 types of assessment styles
#
# - `Manual` - Looking through the data manually in google sheets
# - `Programmatic` - By using pandas functions such as info(), describe() or sample()
#
# ### Steps in Assessment
# There are 2 steps involved in Assessment
#
# - Discover
# - Document

# %%
# Export the DataFrames to an Excel file for manual assessment (currently commented out).

# with pd.ExcelWriter('clinical_trials.xlsx') as writer:
#     patients.to_excel(writer, sheet_name='patients')
#     treatments.to_excel(writer, sheet_name='treatments')
#     treatments_cut.to_excel(writer, sheet_name='treatments_cut')
#     adverse_reactions.to_excel(writer, sheet_name='adverse_reactions')

# %% [markdown]
# ### Issues with the dataset
#
# #**1.Dirty Data**
#
# **Table Patients**
#
#   - patient_id = 9 has misspelled name "Dsvid" of David `accuracy`
#
#   - state col sometimes contain full name and some times abbrivietion `consistency`
#
#   -zip code col has entries with 4 digits `validity`
#
#   -data missing for 12 patients in address, city state zip_code and country, contact `completion`
#
#   -incorrect data types assigned to sex, zip code, birthdate. `validity`
#
#   - duplicate entries by the name of john Doe `accuracy`
#
#   - one patient has weight = 48 pound `accuracy`
#
#   - one patient has height = 27 inches `accuracy`
#
# **Treatments** & **Treatments_cut**
#
#
# - given_name and surname col is all lower case
# `consistency`
#
# - remove u from Auralin and Novodra cols
# `validity`
#
# - in novadra and Auralin col treated as nan
# `validity`
#
# - missing values in hba1c_change`completion`
#
# - 1 duplicate entry by name josph day`accuracy`
#
# - in hba1c_change 9 instead of 4 `accuracy`
#
# #**2.Messy Data**
#
#
# **Table - 'Patients'**
#
#   - contact col contains both phone and email
#
# **Table - 'Treatments'**
#
#   - Auralin and Novadra col should be split into 2 cols start and end
#
#
# **Table -`Adverse_reaction`**
#
#  - this table should not exist independently

# %% [markdown]
# # **Automatic Assesssment**
#
# - head and tail
#
# - sample
#
# - info
#
# - isnull
#
# - duplicated
#
# - describe

# %%
# Display the first 5 rows of the 'patients' DataFrame.
patients.head()
# Out:
#    patient_id assigned_sex given_name  surname                    address  \
# 0           1       female        Zoe  Wellish       576 Brown Bear Drive
# 1           2       female     Pamela     Hill  2370 University Hill Road
# 2           3         male        Jae   Debord      1493 Poling Farm Road
# 3           4         male       Liêm     Phan        2335 Webster Street
# 4           5         male        Tim  Neudorf       1428 Turkey Pen Lane
#
#                 city       state  zip_code        country  \
# 0  Rancho California  California   92390.0  United States
# 1          Armstrong    Illinois   61812.0  United States
# 2               York    Nebraska   68467.0  United States
# 3         Woodbridge          NJ    7095.0  United States
# 4             Dothan          AL   36303.0  United States
#
#                                       contact  birthdate  weight  height   bmi
# 0        951-719-9170ZoeWellish@superrito.com  7/10/1976   121.7      66  19.6
# ...

# %%
# Display the last 5 rows of the 'patients' DataFrame.
patients.tail()
# Out:
#      patient_id assigned_sex given_name      surname  \
# 498         499         male    Mustafa    Lindström
# 499         500         male      Ruman      Bisliev
# 500         501       female      Jinke    de Keizer
# 501         502       female    Chidalu  Onyekaozulu
# 502         503         male        Pat      Gersten
#
#                       address           city     state  zip_code  \
# 498       2530 Victoria Court   Milton Mills        ME    3852.0
# 499  494 Clarksburg Park Road         Sedona        AZ   86341.0
# 500         649 Nutter Street  Overland Park        MO   64110.0
# 501  3652 Boone Crockett Lane        Seattle        WA   98109.0
# 502         2778 North Avenue           Burr  Nebraska   68324.0
#
#            country                                          contact  \
# 498  United States      207-477-0579MustafaLindstrom@jourrapide.com
# 499  United States               928-284-4492RumanBisliev@gustr.com
# ...

# %%
# Display a random sample of rows from the 'patients' DataFrame.
patients.sample()
# Out:
#      patient_id assigned_sex given_name      surname                  address  \
# 371         372       female       Asya  Musliyevich  1763 Williams Mine Road
#
#           city state  zip_code        country  \
# 371  Weehawken    NJ    7087.0  United States
#
#                                           contact  birthdate  weight  height  \
# 371  AsyaMusliyevich@armyspy.com+1 (908) 287-7099  7/15/1995   156.0      63
#
#       bmi
# 371  27.6

# %%
# Get concise summary of the 'patients' DataFrame, including the index dtype and column dtypes, non-null values and memory usage.
patients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   patient_id    503 non-null    int64
#  1   assigned_sex  503 non-null    object
#  2   given_name    503 non-null    object
#  3   surname       503 non-null    object
#  4   address       491 non-null    object
#  5   city          491 non-null    object
#  6   state         491 non-null    object
#  7   zip_code      491 non-null    float64
#  8   country       491 non-null    object
#  9   contact       491 non-null    object
#  10  birthdate     503 non-null    object
#  11  weight        503 non-null    float64
#  12  height        503 non-null    int64
#  13  bmi           503 non-null    float64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 55.1+ KB

# %%
# Count the number of missing values in each column of the 'patients' DataFrame.
patients.isnull().sum()
# Out:
# patient_id       0
# assigned_sex     0
# given_name       0
# surname          0
# address         12
# city            12
# state           12
# zip_code        12
# country         12
# contact         12
# birthdate        0
# weight           0
# height           0
# bmi              0
# dtype: int64

# %%
# Filter the 'patients' DataFrame to show rows where the 'address' column is null.
patients[patients['address'].isnull()]
# Out:
#      patient_id assigned_sex given_name      surname address city state  \
# 209         210       female     Lalita  Eldarkhanov     NaN  NaN   NaN
# 219         220         male         Mỹ        Quynh     NaN  NaN   NaN
# 230         231       female  Elisabeth      Knudsen     NaN  NaN   NaN
# 234         235       female    Martina    Tománková     NaN  NaN   NaN
# 242         243         male       John      O'Brian     NaN  NaN   NaN
# 249         250         male   Benjamin       Mehler     NaN  NaN   NaN
# 257         258         male        Jin         Kung     NaN  NaN   NaN
# 264         265       female   Wafiyyah       Asfour     NaN  NaN   NaN
# 269         270       female     Flavia   Fiorentino     NaN  NaN   NaN
# 278         279       female   Generosa        Cabán     NaN  NaN   NaN
# 286         287         male      Lewis         Webb     NaN  NaN   NaN
# 296         297       female        Chỉ          Lâm     NaN  NaN   NaN
#
# ...

# %%
# Get concise summary of the 'treatments' DataFrame, including the index dtype and column dtypes, non-null values and memory usage.
treatments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   given_name    280 non-null    object
#  1   surname       280 non-null    object
#  2   auralin       280 non-null    object
#  3   novodra       280 non-null    object
#  4   hba1c_start   280 non-null    float64
#  5   hba1c_end     280 non-null    float64
#  6   hba1c_change  171 non-null    float64
# dtypes: float64(3), object(4)
# memory usage: 15.4+ KB

# %%
# Get concise summary of the 'treatments_cut' DataFrame, including the index dtype and column dtypes, non-null values and memory usage.
treatments_cut.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   given_name    70 non-null     object
#  1   surname       70 non-null     object
#  2   auralin       70 non-null     object
#  3   novodra       70 non-null     object
#  4   hba1c_start   70 non-null     float64
#  5   hba1c_end     70 non-null     float64
#  6   hba1c_change  42 non-null     float64
# dtypes: float64(3), object(4)
# memory usage: 4.0+ KB

# %%
# Get concise summary of the 'adverse_reactions' DataFrame, including the index dtype and column dtypes, non-null values and memory usage.
adverse_reactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   given_name        34 non-null     object
#  1   surname           34 non-null     object
#  2   adverse_reaction  34 non-null     object
# dtypes: object(3)
# memory usage: 948.0+ bytes

# %%
# Count the number of duplicate rows in the 'patients' DataFrame based on 'given_name' and 'surname' columns.
patients.duplicated(subset=['given_name','surname']).sum()
# Out:
# np.int64(5)

# %%
# Display the duplicate rows in the 'patients' DataFrame based on 'given_name' and 'surname' columns.
patients[patients.duplicated(subset=['given_name','surname'])]
# Out:
#      patient_id assigned_sex given_name surname          address      city  \
# 229         230         male       John     Doe  123 Main Street  New York
# 237         238         male       John     Doe  123 Main Street  New York
# 244         245         male       John     Doe  123 Main Street  New York
# 251         252         male       John     Doe  123 Main Street  New York
# 277         278         male       John     Doe  123 Main Street  New York
#
#     state  zip_code        country                      contact birthdate  \
# 229    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
# 237    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
# 244    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
# 251    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
# 277    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
#
#      weight  height   bmi
# 229   180.0      72  24.4
# ...

# %%
# Display duplicate rows in the 'treatments' DataFrame.
treatments[treatments.duplicated()]
# Out:
#     given_name surname    auralin novodra  hba1c_start  hba1c_end  \
# 136     joseph     day  29u - 36u       -          7.7       7.19
#
#      hba1c_change
# 136           NaN

# %%
# Display duplicate rows in the 'treatments' DataFrame based on 'given_name' and 'surname'.
treatments[treatments.duplicated(subset=['given_name','surname'])]
# Out:
#     given_name surname    auralin novodra  hba1c_start  hba1c_end  \
# 136     joseph     day  29u - 36u       -          7.7       7.19
#
#      hba1c_change
# 136           NaN

# %%
# Display duplicate rows in the 'treatments_cut' DataFrame based on 'given_name' and 'surname'.
treatments_cut[treatments_cut.duplicated(subset=['given_name','surname'])]
# Out:
# Empty DataFrame
# Columns: [given_name, surname, auralin, novodra, hba1c_start, hba1c_end, hba1c_change]
# Index: []

# %%
# Count the number of duplicate rows in the 'adverse_reactions' DataFrame.
adverse_reactions.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Generate descriptive statistics of the 'patients' DataFrame numerical columns.
patients.describe()
# Out:
#        patient_id      zip_code      weight      height         bmi
# count  503.000000    491.000000  503.000000  503.000000  503.000000
# mean   252.000000  49084.118126  173.434990   66.634195   27.483897
# std    145.347859  30265.807442   33.916741    4.411297    5.276438
# min      1.000000   1002.000000   48.800000   27.000000   17.100000
# 25%    126.500000  21920.500000  149.300000   63.000000   23.300000
# 50%    252.000000  48057.000000  175.300000   67.000000   27.200000
# 75%    377.500000  75679.000000  199.500000   70.000000   31.750000
# max    503.000000  99701.000000  255.900000   79.000000   37.700000

# %%
# Filter the 'patients' DataFrame to show rows where the 'height' is 27.
patients[patients['height'] == 27]
# Out:
#    patient_id assigned_sex given_name  surname               address    city  \
# 4           5         male        Tim  Neudorf  1428 Turkey Pen Lane  Dothan
#
#   state  zip_code        country                          contact  birthdate  \
# 4    AL   36303.0  United States  334-515-7487TimNeudorf@cuvox.de  2/18/1928
#
#    weight  height   bmi
# 4   192.3      27  26.1

# %%
# Generate descriptive statistics of the 'treatments' DataFrame numerical columns.
treatments.describe()
# Out:
#        hba1c_start   hba1c_end  hba1c_change
# count   280.000000  280.000000    171.000000
# mean      7.985929    7.589286      0.546023
# std       0.568638    0.569672      0.279555
# min       7.500000    7.010000      0.200000
# 25%       7.660000    7.270000      0.340000
# 50%       7.800000    7.420000      0.380000
# 75%       7.970000    7.570000      0.920000
# max       9.950000    9.580000      0.990000

# %%
# Sort the 'treatments' DataFrame by 'hba1c_change' with missing values at the top.
treatments.sort_values('hba1c_change',na_position='first')
# Out:
#     given_name      surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0     veronika     jindrová  41u - 48u          -         7.63       7.20
# 2     yukitaka     takenaka          -  39u - 36u         7.68       7.25
# 8        saber       ménard          -  54u - 54u         8.08       7.70
# 9         asia      woźniak  30u - 36u          -         7.76       7.37
# 10      joseph          day  29u - 36u          -         7.70       7.19
# ..         ...          ...        ...        ...          ...        ...
# 49     jackson      addison          -  42u - 42u         7.99       7.51
# 17        gina         cain          -  36u - 36u         7.88       7.40
# 138    giovana        rocha          -  23u - 21u         7.87       7.38
# 32       laura  ehrlichmann          -  43u - 40u         7.95       7.46
# 245         wu         sung          -  47u - 48u         7.61       7.12
#
#      hba1c_change
# 0             NaN
# 2             NaN
# 8             NaN
# ...

# %%
# Generate descriptive statistics of the 'treatments_cut' DataFrame numerical columns.
treatments_cut.describe()
# Out:
#        hba1c_start  hba1c_end  hba1c_change
# count    70.000000  70.000000     42.000000
# mean      7.838000   7.443143      0.518810
# std       0.423007   0.418706      0.270719
# min       7.510000   7.020000      0.280000
# 25%       7.640000   7.232500      0.340000
# 50%       7.730000   7.345000      0.370000
# 75%       7.860000   7.467500      0.907500
# max       9.910000   9.460000      0.970000

# %% [markdown]
# **Note - Assessing Data is an Iterative Process**

# %% [markdown]
# # **Data Quality Dimensions**
#
# - completeness -> data missing?
#
# - validity -> is data invalid -> nagative height -> duplicate patient id
#
# - Accuracy -> data is valid but not accurate ->weight -> 1kg
#
# - Consistency -> both valid and accurate but written differently -> New York and NY

# %% [markdown]
# # **Order of severity**
#
# completeness <- Validity <- Accuracy <- Consistency

# %% [markdown]
# Data Cleaning Order
#
# 1. Quality -> Completeness
#
# 2. Tidness
#
# 3. Quality -> Validity
#
# 4. Quality -> Accuracy
#
# 5. Quality -> Consistency

# %% [markdown]
# # **Steps involved in Data cleaning**
#
# Define
#
# Code
#
# Test
#
# Always make sure to create a copy of your pandas dataframe before you start the cleaning process

# %%
# Create copies of the original DataFrames for cleaning.
patients_df = patients.copy()
treatments_df = treatments.copy()
treatments_cut_df = treatments_cut.copy()
adverse_reactions_df = adverse_reactions.copy()

# %% [markdown]
# #Define
#
# - replace all missing values of patients df with no data
#
# - sub hba1c_start from hba1c_end to get all the change values
#
# - in patients table we will use regex to separate email and phone

# %%
# Display rows with missing address data in the patients_df.
patients_df[patients_df['address'].isnull()]
# Out:
#      patient_id assigned_sex given_name      surname address city state  \
# 209         210       female     Lalita  Eldarkhanov     NaN  NaN   NaN
# 219         220         male         Mỹ        Quynh     NaN  NaN   NaN
# 230         231       female  Elisabeth      Knudsen     NaN  NaN   NaN
# 234         235       female    Martina    Tománková     NaN  NaN   NaN
# 242         243         male       John      O'Brian     NaN  NaN   NaN
# 249         250         male   Benjamin       Mehler     NaN  NaN   NaN
# 257         258         male        Jin         Kung     NaN  NaN   NaN
# 264         265       female   Wafiyyah       Asfour     NaN  NaN   NaN
# 269         270       female     Flavia   Fiorentino     NaN  NaN   NaN
# 278         279       female   Generosa        Cabán     NaN  NaN   NaN
# 286         287         male      Lewis         Webb     NaN  NaN   NaN
# 296         297       female        Chỉ          Lâm     NaN  NaN   NaN
#
# ...

# %%
# Code to replace missing values in patients_df with 'No data'.
patients_df.fillna('No data', inplace=True)

# %%
# Test the fillna operation by checking info of patients_df.
patients_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   patient_id    503 non-null    int64
#  1   assigned_sex  503 non-null    object
#  2   given_name    503 non-null    object
#  3   surname       503 non-null    object
#  4   address       503 non-null    object
#  5   city          503 non-null    object
#  6   state         503 non-null    object
#  7   zip_code      503 non-null    object
#  8   country       503 non-null    object
#  9   contact       503 non-null    object
#  10  birthdate     503 non-null    object
#  11  weight        503 non-null    float64
#  12  height        503 non-null    int64
#  13  bmi           503 non-null    float64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 55.1+ KB

# %%
# Display the head of the treatments_df.
treatments_df.head()
# Out:
#   given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0   veronika    jindrová  41u - 48u          -         7.63       7.20
# 1     elliot  richardson          -  40u - 45u         7.56       7.09
# 2   yukitaka    takenaka          -  39u - 36u         7.68       7.25
# 3       skye  gormanston  33u - 36u          -         7.97       7.62
# 4     alissa      montez          -  33u - 29u         7.78       7.46
#
#    hba1c_change
# 0           NaN
# 1          0.97
# 2           NaN
# 3          0.35
# 4          0.32

# %%
# Code to calculate hba1c_change by subtracting hba1c_end from hba1c_start
treatments_df['hba1c_change'] = treatments_df['hba1c_start'] - treatments_df['hba1c_end']
treatments_cut_df['hba1c_change'] = treatments_cut_df['hba1c_start'] - treatments_cut_df['hba1c_end']

# %%
# Test the hba1c_change calculation by checking info of treatments_cut_df.
treatments_cut_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   given_name    70 non-null     object
#  1   surname       70 non-null     object
#  2   auralin       70 non-null     object
#  3   novodra       70 non-null     object
#  4   hba1c_start   70 non-null     float64
#  5   hba1c_end     70 non-null     float64
#  6   hba1c_change  70 non-null     float64
# dtypes: float64(3), object(4)
# memory usage: 4.0+ KB

# %%
import re
import pandas as pd
import numpy as np

def find_contact_details(text: str) -> tuple:
    # it the value is NaN, then return it
    if pd.isna(text):
        return np.nan, np.nan # Returning both phone and email as NaN

    # create the phone number pattern
    phone_number_pattern = re.compile(r"(\+[\d]{1,3}\s)?(\(?[\d]{3}\)?\s?-?[\d]{3}\s?-?[\d]{4})")
    # find the phone number from the value/text, as a result we will get a list
    phone_number_match  = re.search(phone_number_pattern, text)

    # Extract the phone number from the match object
    if phone_number_match:
        # Concatenate the non-None groups
        phone_number = ''.join([group for group in phone_number_match.groups() if group is not None])
    else:
        phone_number = np.nan

    # if we found the ph number, then remove that part from the actual value.
    # after removing the ph number, the remaining string might be the email address.
    possible_email_add = re.sub(phone_number_pattern, "", text).strip()

    # then return the ph number and the email address
    return phone_number, possible_email_add

# %%
# Apply the function to split the contact column into phone and email.
patients_df['phone'] = patients_df["contact"].apply(lambda x: find_contact_details(x)).apply(lambda x:x[0])
patients_df['email'] = patients_df["contact"].apply(lambda x: find_contact_details(x)).apply(lambda x:x[1])

# %%
# Display the phone column of patients_df.
patients_df['phone']
# Out:
# 0           951-719-9170
# 1      +1 (217) 569-3204
# 2           402-363-6804
# 3      +1 (732) 636-8246
# 4           334-515-7487
#              ...
# 498         207-477-0579
# 499         928-284-4492
# 500         816-223-6007
# 501         360 443 2060
# 502         402-848-4923
# Name: phone, Length: 503, dtype: object

# %%
# Display the email column of patients_df.
patients_df['email']
# Out:
# 0                ZoeWellish@superrito.com
# 1                    PamelaSHill@cuvox.de
# 2                    JaeMDebord@gustr.com
# 3               PhanBaLiem@jourrapide.com
# 4                     TimNeudorf@cuvox.de
#                       ...
# 498       MustafaLindstrom@jourrapide.com
# 499                RumanBisliev@gustr.com
# 500             JinkedeKeizer@teleworm.us
# 501    ChidaluOnyekaozulu@jourrapide.com1
# 502              PatrickGersten@rhyta.com
# Name: email, Length: 503, dtype: object

# %%
# Display the head of patients_df with new phone and email columns.
patients_df.head()
# Out:
#    patient_id assigned_sex given_name  surname                    address  \
# 0           1       female        Zoe  Wellish       576 Brown Bear Drive
# 1           2       female     Pamela     Hill  2370 University Hill Road
# 2           3         male        Jae   Debord      1493 Poling Farm Road
# 3           4         male       Liêm     Phan        2335 Webster Street
# 4           5         male        Tim  Neudorf       1428 Turkey Pen Lane
#
#                 city       state zip_code        country  \
# 0  Rancho California  California  92390.0  United States
# 1          Armstrong    Illinois  61812.0  United States
# 2               York    Nebraska  68467.0  United States
# 3         Woodbridge          NJ   7095.0  United States
# 4             Dothan          AL  36303.0  United States
#
#                                       contact  birthdate  weight  height  \
# 0        951-719-9170ZoeWellish@superrito.com  7/10/1976   121.7      66
# ...

# %%
# Display the head of treatments_df.
treatments_df.head()
# Out:
#   given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0   veronika    jindrová  41u - 48u          -         7.63       7.20
# 1     elliot  richardson          -  40u - 45u         7.56       7.09
# 2   yukitaka    takenaka          -  39u - 36u         7.68       7.25
# 3       skye  gormanston  33u - 36u          -         7.97       7.62
# 4     alissa      montez          -  33u - 29u         7.78       7.46
#
#    hba1c_change
# 0          0.43
# 1          0.47
# 2          0.43
# 3          0.35
# 4          0.32

# %%
# Display the head of treatments_cut_df.
treatments_cut_df.head()
# Out:
#   given_name    surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0      jožka  resanovič  22u - 30u          -         7.56       7.22
# 1  inunnguaq   heilmann  57u - 67u          -         7.85       7.45
# 2      alwin   svensson  36u - 39u          -         7.78       7.34
# 3        thể      lương          -  61u - 64u         7.64       7.22
# 4     amanda    ribeiro  36u - 44u          -         7.85       7.47
#
#    hba1c_change
# 0          0.34
# 1          0.40
# 2          0.44
# 3          0.42
# 4          0.38

# %%
# Concatenate treatments_df and treatments_cut_df into a single DataFrame.
treatments_df = pd.concat([treatments_df, treatments_cut_df])

# %%
# Display the shape of the concatenated treatments_df.
treatments_df.shape
# Out:
# (350, 7)

# %%
# Display the head of the concatenated treatments_df.
treatments_df.head()
# Out:
#   given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0   veronika    jindrová  41u - 48u          -         7.63       7.20
# 1     elliot  richardson          -  40u - 45u         7.56       7.09
# 2   yukitaka    takenaka          -  39u - 36u         7.68       7.25
# 3       skye  gormanston  33u - 36u          -         7.97       7.62
# 4     alissa      montez          -  33u - 29u         7.78       7.46
#
#    hba1c_change
# 0          0.43
# 1          0.47
# 2          0.43
# 3          0.35
# 4          0.32

# %%
# Melt the treatments_df to transform the 'auralin' and 'novodra' columns into rows.
treatments_df = treatments_df.melt(id_vars=['given_name', 'surname','hba1c_start','hba1c_end','hba1c_change'], var_name='type', value_name='dosage_range')

# %%
# Filter out rows where the dosage_range is '-'.
treatments_df = treatments_df[treatments_df['dosage_range'] != '-']

# %%
# Split the 'dosage_range' column into 'dosage_start' and 'dosage_end'.
treatments_df['dosage_start'] = treatments_df['dosage_range'].str.split('-').str.get(0)
treatments_df['dosage_end'] = treatments_df['dosage_range'].str.split('-').str.get(1)

# %%
# Drop the original 'dosage_range' column.
treatments_df.drop(columns=['dosage_range'], inplace=True)

# %%
# Remove 'u' from the 'dosage_start' and 'dosage_end' columns.
treatments_df['dosage_start'] = treatments_df['dosage_start'].str.replace('u', '')
treatments_df['dosage_end'] = treatments_df['dosage_end'].str.replace('u', '')

# %%
# Display the head of the treatments_df after cleaning dosage columns.
treatments_df.head()
# Out:
#   given_name     surname  hba1c_start  hba1c_end  hba1c_change     type  \
# 0   veronika    jindrová         7.63       7.20          0.43  auralin
# 3       skye  gormanston         7.97       7.62          0.35  auralin
# 6     sophia      haugen         7.65       7.27          0.38  auralin
# 7      eddie      archer         7.89       7.55          0.34  auralin
# 9       asia     woźniak         7.76       7.37          0.39  auralin
#
#   dosage_start dosage_end
# 0          41          48
# 3          33          36
# 6          37          42
# 7          31          38
# 9          30          36

# %%
# Display the info of treatments_df to check data types after cleaning dosage columns.
treatments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 350 entries, 0 to 698
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   given_name    350 non-null    object
#  1   surname       350 non-null    object
#  2   hba1c_start   350 non-null    float64
#  3   hba1c_end     350 non-null    float64
#  4   hba1c_change  350 non-null    float64
#  5   type          350 non-null    object
#  6   dosage_start  350 non-null    object
#  7   dosage_end    350 non-null    object
# dtypes: float64(3), object(5)
# memory usage: 24.6+ KB

# %%
# Convert 'dosage_start' and 'dosage_end' columns to integer type.
treatments_df['dosage_start'] = treatments_df['dosage_start'].astype('int')
treatments_df['dosage_end'] = treatments_df['dosage_end'].astype('int')

# %%
# Display the info of treatments_df to confirm data types are updated.
treatments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 350 entries, 0 to 698
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   given_name    350 non-null    object
#  1   surname       350 non-null    object
#  2   hba1c_start   350 non-null    float64
#  3   hba1c_end     350 non-null    float64
#  4   hba1c_change  350 non-null    float64
#  5   type          350 non-null    object
#  6   dosage_start  350 non-null    int64
#  7   dosage_end    350 non-null    int64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 24.6+ KB

# %%
# Merge treatments_df with adverse_reactions_df on given_name and surname.
treatments_df = treatments_df.merge(adverse_reactions_df, on=['given_name', 'surname'], how='left')

# %%
# Export the cleaned treatments_df to a CSV file.
pd.DataFrame.to_csv(treatments_df, 'treatments_df.csv')

# %%
# Display a random sample of 10 rows from the merged treatments_df.
treatments_df.sample(10)
# Out:
#     given_name      surname  hba1c_start  hba1c_end  hba1c_change     type  \
# 339    nebechi    ekechukwu         7.78       7.39          0.39  novodra
# 286     torben    mortensen         7.80       7.40          0.40  novodra
# 338     jeremy      montagu         7.68       7.36          0.32  novodra
# 107      erick        pinto         7.88       7.49          0.39  auralin
# 323     annika        vaara         7.73       7.34          0.39  novodra
# 317       john  teichelmann         7.90       7.58          0.32  novodra
# 221    michael   kristensen         8.51       8.08          0.43  novodra
# 264      tegan      johnson         7.79       7.43          0.36  novodra
# 279        emy       markus         7.53       7.14          0.39  novodra
# 134     mathea      lillebø         9.04       8.67          0.37  auralin
#
#      dosage_start  dosage_end adverse_reaction
# 339            37          39              NaN
# 286            44          40              NaN
# ...

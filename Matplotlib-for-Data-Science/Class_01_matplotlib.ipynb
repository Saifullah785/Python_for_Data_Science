# %% [markdown]
# <a href="https://colab.research.google.com/github/Saifullah785/Python_for_Data_Science/blob/main/Matplotlib-for-Data-Science/Class_01_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Types of Data**
#
# **Numerial Data**
#
# **Categorical Data**

# %%
# importing the library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('fivethirtyeight')

# %% [markdown]
# # **Bivariate Analysis**
#
# categorical -> numerical and numerical ->numerical
#
# Use case -> Time series data

# %%
# plotting a simple function
price = [48000,54000,57000,4900,47000,45000]
year = [2015,2016,2017,2018,2019,2020]

# %%
plt.plot(year,price)
plt.show()

# %%
# from a pandas dataframe
batsman = pd.read_csv('/content/sharma-kohli.csv')
batsman.head()
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364

# %%
plt.plot(batsman['index'],batsman['V Kohli'])
plt.plot(batsman['index'],batsman['RG Sharma'])
plt.show()

# %%
# labels title

plt.plot(batsman['index'],batsman['V Kohli'])
plt.plot(batsman['index'],batsman['RG Sharma'])
plt.title('V Kohli vs RG Sharma')
plt.xlabel('Season')
plt.ylabel('Runs')
plt.show()

# %%
# colors (hex) and line (width and style) and marker (size)

plt.plot(batsman['index'],batsman['V Kohli'],color= 'blue',linestyle= 'solid',linewidth=4)
plt.plot(batsman['index'],batsman['RG Sharma'],color= 'red',linestyle='dotted') # dashdot,dashed
plt.title('V Kohli vs RG Sharma')
plt.xlabel('Season')
plt.ylabel('Runs')
plt.show()

# %%
#marker (size)
plt.plot(batsman['index'],batsman['V Kohli'],color= 'blue',linestyle= 'solid',linewidth=4 , marker='D',markersize=10)
plt.plot(batsman['index'],batsman['RG Sharma'],color= 'red',linestyle='dotted') # dashdot,dashed
plt.title('V Kohli vs RG Sharma')
plt.xlabel('Season')
plt.ylabel('Runs')
plt.show()

# %%
# legend -> location
plt.plot(batsman['index'],batsman['V Kohli'],color= 'blue',linestyle= 'solid',linewidth=4 , marker='D',markersize=10, label= 'Virat')
plt.plot(batsman['index'],batsman['RG Sharma'],color= 'red',linestyle='dotted',label='Rohit') # dashdot,dashed
plt.title('V Kohli vs RG Sharma')
plt.xlabel('Season')
plt.ylabel('Runs')
plt.legend(loc='upper left')
plt.show()

# %%
# limiting axes

price = [48000,54000,57000,4900,47000,45000,4500000]
year = [2015,2016,2017,2018,2019,2020,2021]
plt.plot(year,price)
plt.xlim(2015,2021)
plt.ylim(0,75000)
plt.show()

# %%
# grid
plt.plot(batsman['index'],batsman['V Kohli'],color= 'blue',linestyle= 'solid',linewidth=4 , marker='D',markersize=10, label= 'Virat')
plt.plot(batsman['index'],batsman['RG Sharma'],color= 'red',linestyle='dotted',label='Rohit') # dashdot,dashed
plt.title('V Kohli vs RG Sharma')
plt.xlabel('Season')
plt.ylabel('Runs')
plt.legend(loc='upper left')

plt.show() # show

# %% [markdown]
# # Scatter Plots
#
# Bivariate Analysis
#
# numerical vs numerical
#
# Use case finding correlation

# %%
# plt.scatter simple function
x = np.linspace(-10,10,50)

y = 10*x + 3 + np.random.randint(0,300,50)

y
# Out:
# array([-92.        , 125.08163265,  87.16326531, 165.24489796,
#        129.32653061, 215.40816327, 148.48979592, 113.57142857,
#         60.65306122,  16.73469388,  62.81632653, 200.89795918,
#        198.97959184, 255.06122449, 165.14285714, 176.2244898 ,
#        260.30612245, -23.6122449 ,  -9.53061224,  78.55102041,
#         48.63265306,  -5.28571429, 284.79591837, 171.87755102,
#         44.95918367,   5.04081633,  38.12244898, 297.20408163,
#        231.28571429,  39.36734694, 302.44897959, 322.53061224,
#        111.6122449 , 315.69387755, 104.7755102 , 256.85714286,
#        213.93877551, 273.02040816,  76.10204082, 316.18367347,
#         71.26530612, 356.34693878, 346.42857143, 319.51020408,
#        309.59183673, 272.67346939, 254.75510204, 283.83673469,
#        160.91836735, 119.        ])

# %%
plt.scatter(x,y)

# %%
# plt.scatter on pandas data
df = pd.read_csv('/content/batter.csv')
df=df.head(50)
df
# Out:
#             batter  runs        avg  strike_rate
# 0          V Kohli  6634  36.251366   125.977972
# 1         S Dhawan  6244  34.882682   122.840842
# 2        DA Warner  5883  41.429577   136.401577
# 3        RG Sharma  5881  30.314433   126.964594
# 4         SK Raina  5536  32.374269   132.535312
# 5   AB de Villiers  5181  39.853846   148.580442
# 6         CH Gayle  4997  39.658730   142.121729
# 7         MS Dhoni  4978  39.196850   130.931089
# 8       RV Uthappa  4954  27.522222   126.152279
# 9       KD Karthik  4377  26.852761   129.267572
# 10       G Gambhir  4217  31.007353   119.665153
# 11       AT Rayudu  4190  28.896552   124.148148
# 12       AM Rahane  4074  30.863636   117.575758
# 13        KL Rahul  3895  46.927711   132.799182
# 14       SR Watson  3880  30.793651   134.163209
# 15       MK Pandey  3657  29.731707   117.739858
# 16       SV Samson  3526  29.140496   132.407060
# 17      KA Pollard  3437  28.404959   140.457703
# ...

# %%
plt.scatter(df['avg'],df['strike_rate'],color='red',marker='D')
plt.title('Avg vs Strike Rate')
plt.xlabel('Avg')
plt.ylabel('Strike Rate')
plt.show()

# %%
# marker

# %%
# size
tips = sns.load_dataset('tips')

tips.head()
plt.scatter(tips['total_bill'],tips['tip'],s=tips['size']*20)
plt.title('Total Bill vs Tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# %%
# scatterplot using plt.plot
plt.plot(tips['total_bill'],tips['tip'],'o')
plt.title('Total Bill vs Tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

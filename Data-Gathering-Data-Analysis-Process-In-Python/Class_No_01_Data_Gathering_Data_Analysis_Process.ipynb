# %% [markdown]
# <a href="https://colab.research.google.com/github/Saifullah785/Python_for_Data_Science/blob/main/Data-Gathering-Data-Analysis-Process-In-Python/Class_No_01_Data_Gathering_Data_Analysis_Process.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **What is Data Analysis**
#
# Data analysis is a process of inpecting, cleansing, transforming and modeling data with the goal of discovering useful information, informing conclusions and supporting decision-making.
#
# #**Step1.Data Analysis Process**
#
# **Asking Questions**
#
# 1.What features will contribute to my analysis?
#
# 2.What features are not important fo my analysis?
#
# 3.Which of the features have a strong correlation?
#
# 4.Do i need data Preprocessing?
#
# 5.What kind of feature manipulation/engineering is required?
#
# #**How can i ask better questions?**
#
# **Subject Matter Expertise** -> **Experience**
#
#
# #**Step 2.Data Wrangling**/**Munging**
#
# Data wrangling, sometimes referred to as data munging, is the process of transforming and mappping data from one "raw" data from into another formate with the intent of making it more appropriate and valuable for a variety of downstream purpose such as analytics.
#
# **2a:Gathering Data**
#
# CSV Files
#
# https://github.com/Saifullah785/machine-learning-engineer-roadmap/blob/main/Lecture_15_working_with_csv_files/Lecture_15_working_with_csv_files.ipynb
#
# APi
#
# Web Scraping
#
# Databases

# %%
# importing excel file from github
import pandas as pd

# %%
# Use the raw URL to directly access the Excel file content
excel_url = 'https://github.com/Saifullah785/Data_Analysis_Project_Excel/raw/main/Data_Analysis_Project.xlsx'

pd.read_excel(excel_url, index_col=0)
# Out:
# /usr/local/lib/python3.11/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Slicer List extension is not supported and will be removed
#   warn(msg)
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.read_excel(excel_url, index_col=0, sheet_name=1)
# Out:
#                Unnamed: 1         Unnamed: 2
# NaN                   NaN                NaN
# Row Labels  Sum of Amount  Count of Order ID
# Jan               1820601               2702
# Feb               1875932               2750
# Mar               1928066               2819
# Apr               1829263               2685
# May               1797822               2617
# Jun               1750966               2597
# Jul               1772300               2579
# Aug               1808505               2617
# Sep               1688871               2490
# Oct               1666662               2424
# Nov               1615356               2383
# Dec               1622033               2384

# %%
# pd.read_excel('output.xlsx', sheet_name='sheet_name_2')
# pd.read.excel('output.xlsx', index_col='Unnamed: 0')

# %%
# importing .txt data from github
txt_url = 'https://github.com/dwyl/english-words/blob/master/words_alpha.txt'

pd.read_csv(txt_url, header=None, sep='\t')#
# Out:
#                                                       0
# 0                                       <!DOCTYPE html>
# 1                                                 <html
# 2                                             lang="en"
# 3       data-color-mode="auto" data-light-theme="lig...
# 4       data-a11y-animated-images="system" data-a11y...
# ...                                                 ...
# 1478                                             </div>
# 1479      <div id="js-global-screen-reader-notice" c...
# 1480      <div id="js-global-screen-reader-notice-as...
# 1481                                            </body>
# 1482                                            </html>
#
# [1483 rows x 1 columns]

# %% [markdown]
# **2b.Assessing Data**
#
# 1.finding the number of row/columns(shape)
#
# 2.Data types of various columns (info())
#
# 3.Checking for missing values (info())
#
# 4.Check for duplicate data (is_unique)
#
# 5.Memory occupied by the dataset (info)
#
# 6.High level mathematical overview of the data(describe)
#
#
# **2C.Cleaning Data**
#
# 1.Missing Data (e.g mean)
#
# 2.Remove duplicate data (drop_duplicates)
#
# 3.Incorrect data types (astype)
#
# #**Step 3 : Exploratory Data Analysis**
#
# **3a:Exploring Data**
#
# 1.Finding Correlation and Covariance
#
# 2.Doing Univariate and multivariate analysis
#
# 3.Plotting graphs (data visualization)
#
#
# **3b : Augmenting Data**
#
# 1.Removing Outliers
#
# 2.Merging Dataframes
#
# 3.Adding new column
#
# These operations are collectively called as Feature Engineering
#
#
#
# #**Drawing Conclusions**
#
# Machine Learning
#
# Inferential Statistics
#
# Descriptive Statistics
#
# Some example conclusions based on Descriptive Statistics
#
# 1.Is Rohit Sharma a better batsman in 2nd innings(IPL Dataset)?
#
# 2.Does being a female increase your chances of Survival (Titanic Dataset)?
#
# 3.Is Delhi the most costly place for eating out(Zomato Dataset)?
#
# #**Communicating Results / Data Storytellig**
#
# In person
#
# Reports
#
# Blog Post
#
# PPTs / Slide decks

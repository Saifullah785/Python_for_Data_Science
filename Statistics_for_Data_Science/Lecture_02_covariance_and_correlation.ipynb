# %% [markdown]
# <a href="https://colab.research.google.com/github/Saifullah785/Python_for_Data_Science/blob/main/Statistics_for_Data_Science/Lecture_02_covariance_and_correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Initialize an empty DataFrame
df = pd.DataFrame()

# %%
# Define Series x and y
from re import X
x = pd.Series([12,25,68,48,113])
y = pd.Series([12,29,58,121,100])

# %%
# Add Series x and y to DataFrame df
df['x'] = x
df['y'] = y

# %%
# Display the DataFrame df
df
# Out:
#      x    y
# 0   12   12
# 1   25   29
# 2   68   58
# 3   48  121
# 4  113  100

# %%
# Plot scatterplots for x vs y and x vs 2*y with covariance titles
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(10,3))
ax1.scatter(df['x'], df['y'])
ax2.scatter(df['x'], df['y']*2)

ax1.set_title("Covariance -" + str(np.cov(df['x'], df['y'])[0,1]))
ax2.set_title("Covariance -" + str(np.cov(df['x']*2, df['y']*2)[0,1]))
# Out:
# Text(0.5, 1.0, 'Covariance -4897.0')

# %%
# Print covariance values
print(np.cov(df['x'], df['y'])[0,1])
print(np.cov(df['x']*2, df['y']*2)[0,1])
# Out:
# 1224.25
# 4897.0

# %%
# Plot scatterplots with covariance titles
fig, ax = plt.subplots(1,3, figsize=(15,3))

# plot scatterplots on each axes
ax[0].scatter(df['x'],df['x'])
ax[1].scatter(df['x'],df['y'])
ax[2].scatter(df['x']*2, df['y']*2)

ax[0].set_title("Converiance - " + str(np.cov(df['x'],df['x'])[0,1]))
ax[0].set_title("Converiance - " + str(np.cov(df['x'],df['y'])[0,1]))
ax[2].set_title("Converiance - " + str(np.cov(df['x']*2, df['y']*2)[0,1]))
# Out:
# Text(0.5, 1.0, 'Converiance - 4897.0')

# %% [markdown]
# # Correlation

# %%
# Plot scatterplots with correlation titles
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10, 3))
# Plot scatterplots on each axes
ax1.scatter(df['x'], df['y'])
ax2.scatter(df['x'], df['y'])

ax1.set_title("Correlation - " + str(df['x'].corr(df['x'])))
ax2.set_title("Correlation - " + str(df['x'].corr(df['y'])))
# Out:
# Text(0.5, 1.0, 'Correlation - 0.6680139376549898')

# %%
# Plot scatterplots for correlation demonstration
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10, 3))
# Plot scatterplots on each axes
ax1.scatter(df['x'], df['y'])
ax2.scatter(df['x']*2, df['y'])

ax1.set_title("Correlation - " + str(df['x'].corr(df['y'])))
ax2.set_title("Correlation - " + str((df['x']*2).corr(df['y']*2)))
# Out:
# Text(0.5, 1.0, 'Correlation - 0.6680139376549898')

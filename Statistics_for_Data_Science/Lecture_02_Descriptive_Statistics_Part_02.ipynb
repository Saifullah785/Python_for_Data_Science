# %% [markdown]
# <a href="https://colab.research.google.com/github/Saifullah785/Python_for_Data_Science/blob/main/Statistics_for_Data_Science/Lecture_02_Descriptive_Statistics_Part_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.DataFrame()

# %%
from re import X
x = pd.Series([12,25,68,48,113])
y = pd.Series([12,29,58,121,100])

# %%
df['x'] = x
df['y'] = y

# %%
df
# Out:
#      x    y
# 0   12   12
# 1   25   29
# 2   68   58
# 3   48  121
# 4  113  100

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(10,3))
ax1.scatter(df['x'], df['y'])
ax2.scatter(df['x'], df['y']*2)

ax1.set_title("Covariance -" + str(np.cov(df['x'], df['y'])[0,1]))
ax2.set_title("Covariance -" + str(np.cov(df['x']*2, df['y']*2)[0,1]))
# Out:
# Text(0.5, 1.0, 'Covariance -4897.0')
